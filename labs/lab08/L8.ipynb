# %%
import Pkg
Pkg.add("JuMP")
Pkg.add("GLPK")
using JuMP
using GLPK
# Out:
#     Updating registry at `C:\Users\eldar\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed CodecBzip2 ─────── v0.8.5
#    Installed JuMP ───────────── v1.30.0
#    Installed MathOptInterface ─ v1.49.0
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#   [4076af6c] + JuMP v1.30.0
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#   [523fee87] + CodecBzip2 v0.8.5
#   [4076af6c] + JuMP v1.30.0
#   [b8f27783] + MathOptInterface v1.49.0
# Precompiling packages...
#    9215.0 ms  ✓ CodecBzip2
#    6895.3 ms  ? StochasticDiffEq
#    8129.0 ms  ? DifferentialEquations
#   40527.3 ms  ✓ MathOptInterface
#   22595.2 ms  ✓ JuMP
#    2302.9 ms  ✓ SparseMatrixColorings → SparseMatrixColoringsJuMPExt
#   4 dependencies successfully precompiled in 126 seconds. 634 already precompiled.
#   2 dependencies failed but may be precompilable after restarting julia
#   2 dependencies had output during precompilation:
# ┌ StochasticDiffEq
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DifferentialEquations
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
#    Resolving package versions...
#    Installed GLPK ───── v1.2.1
#    Installed GLPK_jll ─ v5.0.1+1
#   Installing 1 artifacts
#    Installed artifact GLPK                  3.2 MiB
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#   [60bf3e95] + GLPK v1.2.1
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#   [60bf3e95] + GLPK v1.2.1
#   [e8aa6df9] + GLPK_jll v5.0.1+1
#   [781609d7] + GMP_jll v6.3.0+2
# Precompiling packages...
#    1116.6 ms  ✓ GLPK_jll
#    5454.5 ms  ✓ GLPK
#    5786.0 ms  ? StochasticDiffEq
#    6894.1 ms  ? DifferentialEquations
#   2 dependencies successfully precompiled in 16 seconds. 639 already precompiled.
#   2 dependencies failed but may be precompilable after restarting julia
#   2 dependencies had output during precompilation:
# ┌ StochasticDiffEq
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DifferentialEquations
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └

# %%
# Определение объекта модели с именем model:
model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# ├ solver: GLPK
# ├ objective_sense: FEASIBILITY_SENSE
# ├ num_variables: 0
# ├ num_constraints: 0
# └ Names registered in the model: none

# %%
# Определение переменных x, y и граничных условий для них:
@variable(model, x >= 0)
@variable(model, y >= 0)
# Out:
# y

# %%
# Определение ограничений модели:
@constraint(model, 6x + 8y >= 100)
@constraint(model, 7x + 12y >= 120)
# Out:
# 7 x + 12 y >= 120

# %%
# Определение целевой функции:
@objective(model, Min, 12x + 20y)
# Out:
# 12 x + 20 y

# %%
# Вызов функции оптимизации:
optimize!(model)

# %%
# Определение причины завершения работы оптимизатора:
termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
# Демонстрация первичных результирующих значений переменных x и y:
@show value(x);
@show value(y);
# Демонстрация результата оптимизации:
@show objective_value(model);
# Out:
# value(x) = 14.999999999999993
# value(y) = 1.2500000000000047
# objective_value(model) = 205.0

# %%
# Подключение пакетов:
import Pkg
Pkg.add("JuMP")
Pkg.add("GLPK")
using JuMP
using GLPK
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    5165.2 ms  ? StochasticDiffEq
#    7080.8 ms  ? DifferentialEquations
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    4936.8 ms  ? StochasticDiffEq
#    6819.6 ms  ? DifferentialEquations

# %%
# Определение объекта модели с именем vector_model:
vector_model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# ├ solver: GLPK
# ├ objective_sense: FEASIBILITY_SENSE
# ├ num_variables: 0
# ├ num_constraints: 0
# └ Names registered in the model: none

# %%
# Определение начальных данных:
A= [ 1 1 9 5;
3 5 0 8;
2 0 6 13]
b = [7; 3; 5]
c = [1; 3; 5; 2]
# Out:
# 4-element Vector{Int64}:
#  1
#  3
#  5
#  2

# %%
# Определение вектора переменных:
@variable(vector_model, x[1:4] >= 0)
# Out:
# 4-element Vector{VariableRef}:
#  x[1]
#  x[2]
#  x[3]
#  x[4]

# %%
# Определение ограничений модели:
@constraint(vector_model, A * x .== b)
# Out:
# 3-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  x[1] + x[2] + 9 x[3] + 5 x[4] == 7
#  3 x[1] + 5 x[2] + 8 x[4] == 3
#  2 x[1] + 6 x[3] + 13 x[4] == 5

# %%
# Определение целевой функции:
@objective(vector_model, Min, c' * x)
# Out:
# x[1] + 3 x[2] + 5 x[3] + 2 x[4]

# %%
# Вызов функции оптимизации:
optimize!(vector_model)

# %%
# Определение причины завершения работы оптимизатора:
termination_status(vector_model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
# Демонстрация результата оптимизации:
@show objective_value(vector_model);
# Out:
# objective_value(vector_model) = 4.9230769230769225

# %%
# Подключение пакетов:
import Pkg
Pkg.add("JuMP")
Pkg.add("GLPK")
using JuMP
using GLPK
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    5456.9 ms  ? StochasticDiffEq
#    7995.1 ms  ? DifferentialEquations
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    5177.5 ms  ? StochasticDiffEq
#    7292.8 ms  ? DifferentialEquations

# %%
# Контейнер для хранения данных об ограничениях на количество потребляемых калорий, белков, жиров и соли:
category_data = JuMP.Containers.DenseAxisArray(
    [1800 2200;
    91 Inf;
    0 65;
    0 1779],
    ["calories", "protein", "fat", "sodium"],
    ["min", "max"])
# Out:
# 2-dimensional DenseAxisArray{Float64,2,...} with index sets:
#     Dimension 1, ["calories", "protein", "fat", "sodium"]
#     Dimension 2, ["min", "max"]
# And data, a 4×2 Matrix{Float64}:
#  1800.0  2200.0
#    91.0    Inf
#     0.0    65.0
#     0.0  1779.0

# %%
# массив данных с наименованиями продуктов:
foods = ["hamburger", "chicken", "hot dog", "fries", "macaroni", "pizza","salad", "milk", "ice cream"]
# Out:
# 9-element Vector{String}:
#  "hamburger"
#  "chicken"
#  "hot dog"
#  "fries"
#  "macaroni"
#  "pizza"
#  "salad"
#  "milk"
#  "ice cream"

# %%
# Массив стоимости продуктов:
cost = JuMP.Containers.DenseAxisArray(
[2.49, 2.89, 1.50, 1.89, 2.09, 1.99, 2.49, 0.89, 1.59],
foods)
# Out:
# 1-dimensional DenseAxisArray{Float64,1,...} with index sets:
#     Dimension 1, ["hamburger", "chicken", "hot dog", "fries", "macaroni", "pizza", "salad", "milk", "ice cream"]
# And data, a 9-element Vector{Float64}:
#  2.49
#  2.89
#  1.5
#  1.89
#  2.09
#  1.99
#  2.49
#  0.89
#  1.59

# %%
# Массив данных о содержании калорий, белков, жиров и соли в продуктах питания:
food_data = JuMP.Containers.DenseAxisArray(
[410 24 26 730;
420 32 10 1190;
560 20 32 1800;
380 4 19 270;
320 12 10 930;
320 15 12 820;
320 31 12 1230;
100 8 2.5 125;
330 8 10 180],
foods,
["calories", "protein", "fat", "sodium"])
# Out:
# 2-dimensional DenseAxisArray{Float64,2,...} with index sets:
#     Dimension 1, ["hamburger", "chicken", "hot dog", "fries", "macaroni", "pizza", "salad", "milk", "ice cream"]
#     Dimension 2, ["calories", "protein", "fat", "sodium"]
# And data, a 9×4 Matrix{Float64}:
#  410.0  24.0  26.0   730.0
#  420.0  32.0  10.0  1190.0
#  560.0  20.0  32.0  1800.0
#  380.0   4.0  19.0   270.0
#  320.0  12.0  10.0   930.0
#  320.0  15.0  12.0   820.0
#  320.0  31.0  12.0  1230.0
#  100.0   8.0   2.5   125.0
#  330.0   8.0  10.0   180.0

# %%
# Определение объекта модели с именем model:
model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# ├ solver: GLPK
# ├ objective_sense: FEASIBILITY_SENSE
# ├ num_variables: 0
# ├ num_constraints: 0
# └ Names registered in the model: none

# %%
# Определим массив:
categories = ["calories", "protein", "fat", "sodium"]
# Out:
# 4-element Vector{String}:
#  "calories"
#  "protein"
#  "fat"
#  "sodium"

# %%
# Определение переменных:
@variables(model, begin
category_data[c, "min"] <= nutrition[c = categories] <= category_data[c, "max"]
# Сколько покупать продуктов:
buy[foods] >= 0
end)
# Out:
# (1-dimensional DenseAxisArray{VariableRef,1,...} with index sets:
#     Dimension 1, ["calories", "protein", "fat", "sodium"]
# And data, a 4-element Vector{VariableRef}:
#  nutrition[calories]
#  nutrition[protein]
#  nutrition[fat]
#  nutrition[sodium], 1-dimensional DenseAxisArray{VariableRef,1,...} with index sets:
#     Dimension 1, ["hamburger", "chicken", "hot dog", "fries", "macaroni", "pizza", "salad", "milk", "ice cream"]
# And data, a 9-element Vector{VariableRef}:
#  buy[hamburger]
#  buy[chicken]
#  buy[hot dog]
#  buy[fries]
#  buy[macaroni]
#  buy[pizza]
#  buy[salad]
#  buy[milk]
#  buy[ice cream])

# %%
# Определение целевой функции:
@objective(model, Min, sum(cost[f] * buy[f] for f in foods))
# Out:
# 2.49 buy[hamburger] + 2.89 buy[chicken] + 1.5 buy[hot dog] + 1.89 buy[fries] + 2.09 buy[macaroni] + 1.99 buy[pizza] + 2.49 buy[salad] + 0.89 buy[milk] + 1.59 buy[ice cream]

# %%
# Определение ограничений модели:
@constraint(model, [c in categories],
sum(food_data[f, c] * buy[f] for f in foods) == nutrition[c]
)
# Out:
# 1-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},1,...} with index sets:
#     Dimension 1, ["calories", "protein", "fat", "sodium"]
# And data, a 4-element Vector{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  -nutrition[calories] + 410 buy[hamburger] + 420 buy[chicken] + 560 buy[hot dog] + 380 buy[fries] + 320 buy[macaroni] + 320 buy[pizza] + 320 buy[salad] + 100 buy[milk] + 330 buy[ice cream] == 0
#  -nutrition[protein] + 24 buy[hamburger] + 32 buy[chicken] + 20 buy[hot dog] + 4 buy[fries] + 12 buy[macaroni] + 15 buy[pizza] + 31 buy[salad] + 8 buy[milk] + 8 buy[ice cream] == 0
#  -nutrition[fat] + 26 buy[hamburger] + 10 buy[chicken] + 32 buy[hot dog] + 19 buy[fries] + 10 buy[macaroni] + 12 buy[pizza] + 12 buy[salad] + 2.5 buy[milk] + 10 buy[ice cream] == 0
#  -nutrition[sodium] + 730 buy[hamburger] + 1190 buy[chicken] + 1800 buy[hot dog] + 270 buy[fries] + 930 buy[macaroni] + 820 buy[pizza] + 1230 buy[salad] + 125 buy[milk] + 180 buy[ice cream] == 0

# %%
# Вызов функции оптимизации:
JuMP.optimize!(model)
term_status = JuMP.termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
hcat(buy.data,JuMP.value.(buy.data))
# Out:
# 9×2 Matrix{AffExpr}:
#  buy[hamburger]  0.6045138888888888
#  buy[chicken]    0
#  buy[hot dog]    0
#  buy[fries]      0
#  buy[macaroni]   0
#  buy[pizza]      0
#  buy[salad]      0
#  buy[milk]       6.9701388888888935
#  buy[ice cream]  2.591319444444441

# %%
# Скачиваем данные с ресурса на git:
;git clone https://github.com/ilyankou/passport-index-dataset.git
# Out:
# Cloning into 'passport-index-dataset'...

# %%
# Подключение пакетов:
import Pkg
Pkg.add("DelimitedFiles")
Pkg.add("CSV")
using DelimitedFiles
using CSV
# Out:
#    Resolving package versions...
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#   [8bb1440f] + DelimitedFiles v1.9.1
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    6124.8 ms  ? StochasticDiffEq
#    8204.2 ms  ? DifferentialEquations
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    5311.2 ms  ? StochasticDiffEq
#    7310.4 ms  ? DifferentialEquations

# %%
# Считывание данных:
passportdata = readdlm(joinpath("passport-index-dataset","passport-index-matrix.csv"),',')
# Out:
# 200×200 Matrix{Any}:
#  "Passport"                 "Albania"  …    "Afghanistan"
#  "Afghanistan"              "e-visa"      -1
#  "Albania"                -1                "visa required"
#  "Algeria"                  "e-visa"        "visa required"
#  "Andorra"                90                "visa required"
#  "Angola"                   "e-visa"   …    "visa required"
#  "Antigua and Barbuda"    90                "visa required"
#  "Argentina"              90                "visa required"
#  "Armenia"                90                "visa required"
#  "Australia"              90                "visa required"
#  "Austria"                90           …    "visa required"
#  "Azerbaijan"             90                "visa required"
#  "Bahamas"                90                "visa required"
#  ⋮                                     ⋱
#  "United Arab Emirates"   90                "visa required"
#  "United Kingdom"         90                "visa required"
#  "United States"         360           …    "visa required"
#  "Uruguay"                90                "visa required"
#  "Uzbekistan"               "e-visa"        "visa required"
#  "Vanuatu"                  "e-visa"        "visa required"
#  "Vatican"                90                "visa required"
#  "Venezuela"              90           …    "visa required"
#  "Vietnam"                  "e-visa"        "visa required"
#  "Yemen"                    "e-visa"        "visa required"
#  "Zambia"                   "e-visa"        "visa required"
#  "Zimbabwe"                 "e-visa"        "visa required"

# %%
# Подключение пакетов:
Pkg.add("JuMP")
Pkg.add("GLPK")
using JuMP
using GLPK
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`

# %%
# Задаём переменные:
cntr = passportdata[2:end,1]
vf = (x -> typeof(x)==Int64 || x == "VF" || x == "VOA" ? 1 : 0).(passportdata[2:end,2:end]);

# %%
# Определение объекта модели с именем model:
model = Model(GLPK.Optimizer)
# Out:
# A JuMP Model
# ├ solver: GLPK
# ├ objective_sense: FEASIBILITY_SENSE
# ├ num_variables: 0
# ├ num_constraints: 0
# └ Names registered in the model: none

# %%
# Переменные, ограничения и целевая функция:
@variable(model, pass[1:length(cntr)], Bin)
@constraint(model, [j=1:length(cntr)], sum( vf[i,j]*pass[i] for i in 1:length(cntr)) >= 1)
@objective(model, Min, sum(pass))
# Out:
# pass[1] + pass[2] + pass[3] + pass[4] + pass[5] + pass[6] + pass[7] + pass[8] + pass[9] + pass[10] + pass[11] + pass[12] + pass[13] + pass[14] + pass[15] + pass[16] + pass[17] + pass[18] + pass[19] + pass[20] + pass[21] + pass[22] + pass[23] + pass[24] + pass[25] + pass[26] + pass[27] + pass[28] + pass[29] + pass[30] + [[...139 terms omitted...]] + pass[170] + pass[171] + pass[172] + pass[173] + pass[174] + pass[175] + pass[176] + pass[177] + pass[178] + pass[179] + pass[180] + pass[181] + pass[182] + pass[183] + pass[184] + pass[185] + pass[186] + pass[187] + pass[188] + pass[189] + pass[190] + pass[191] + pass[192] + pass[193] + pass[194] + pass[195] + pass[196] + pass[197] + pass[198] + pass[199]

# %%
# Вызов функции оптимизации:
JuMP.optimize!(model)
termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
# Просмотр результата:
print(JuMP.objective_value(model)," passports: ",join(cntr[findall(JuMP.value.(pass) .== 1)],", "))
# Out:
# 34.0 passports: Afghanistan, Australia, Bahrain, Cameroon, Comoros, Congo, Djibouti, Dominican Republic, Eritrea, Guinea-Bissau, Hong Kong, Iran, Kenya, Kuwait, Liberia, Libya, Madagascar, Maldives, Mauritania, Morocco, Nepal, New Zealand, North Korea, Palestine, Papua New Guinea, Qatar, Saudi Arabia, Singapore, Somalia, South Sudan, Spain, Syria, Turkmenistan, United States

# %%
# Подключение необходимых пакетов:
import Pkg
Pkg.add("DataFrames")
Pkg.add("XLSX")
Pkg.add("Plots")
Pkg.add("PyPlot")
Pkg.add("Convex")
Pkg.add("SCS")
Pkg.add("Statistics")
using DataFrames
using XLSX
using Plots
pyplot()
using Convex
using SCS
using Statistics
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    6164.1 ms  ? StochasticDiffEq
#    7973.1 ms  ? DifferentialEquations
#    Resolving package versions...
#    Installed ZipFile ──────── v0.10.1
#    Installed XML2_jll ─────── v2.15.1+0
#    Installed InputBuffers ─── v1.1.1
#    Installed CodecInflate64 ─ v0.1.3
#    Installed ZipArchives ──── v2.6.0
#    Installed ArgCheck ─────── v2.5.0
#    Installed EzXML ────────── v1.2.3
#    Installed XLSX ─────────── v0.10.4
#   Installing 2 artifacts
#    Installed artifact XLSX_relocatable_data 6.0 KiB
#    Installed artifact XML2                  2.8 MiB
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#   [fdbf4ff8] + XLSX v0.10.4
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#   [dce04be8] + ArgCheck v2.5.0
#   [6309b1aa] + CodecInflate64 v0.1.3
#   [8f5d6c58] + EzXML v1.2.3
#   [0c81fc1b] + InputBuffers v1.1.1
#   [fdbf4ff8] + XLSX v0.10.4
#   [49080126] + ZipArchives v2.6.0
#   [a5390f91] + ZipFile v0.10.1
#   [02c8fc9c] + XML2_jll v2.15.1+0
# Precompiling packages...
#    1802.6 ms  ✓ ArgCheck
#    1571.3 ms  ✓ InputBuffers
#    1913.6 ms  ✓ ZipFile
#    1935.2 ms  ✓ CodecInflate64
#    1883.4 ms  ✓ XML2_jll
#    1225.3 ms  ✓ EzXML
#    5788.3 ms  ✓ ZipArchives
#    6849.1 ms  ? StochasticDiffEq
#    1707.1 ms  ✓ XLSX
#    6958.2 ms  ? DifferentialEquations
#   8 dependencies successfully precompiled in 18 seconds. 641 already precompiled.
#   2 dependencies failed but may be precompilable after restarting julia
#   2 dependencies had output during precompilation:
# ┌ StochasticDiffEq
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DifferentialEquations
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    5168.1 ms  ? StochasticDiffEq
#    7080.2 ms  ? DifferentialEquations
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    4943.5 ms  ? StochasticDiffEq
#    7135.4 ms  ? DifferentialEquations
#    Resolving package versions...
#    Installed LDLFactorizations ─ v0.10.1
#    Installed AMD ─────────────── v0.5.3
#    Installed Convex ──────────── v0.16.5
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#   [f65535da] + Convex v0.16.5
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#   [14f7f29c] + AMD v0.5.3
#   [f65535da] + Convex v0.16.5
#   [40e66cde] + LDLFactorizations v0.10.1
# Precompiling packages...
#    1286.7 ms  ✓ AMD
#     819.6 ms  ✓ LDLFactorizations
#    5557.5 ms  ? StochasticDiffEq
#    6669.3 ms  ✓ Convex
#    7676.7 ms  ? DifferentialEquations
#   3 dependencies successfully precompiled in 17 seconds. 649 already precompiled.
#   2 dependencies failed but may be precompilable after restarting julia
#   2 dependencies had output during precompilation:
# ┌ StochasticDiffEq
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DifferentialEquations
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
#    Resolving package versions...
#    Installed SCS_jll ─ v300.200.1100+0
#    Installed SCS ───── v2.6.3
#   Installing 1 artifacts
#    Installed artifact SCS                   938.8 KiB
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#   [c946c3f1] + SCS v2.6.3
#     Updating `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#   [c946c3f1] + SCS v2.6.3
#   [f4f2fc5b] + SCS_jll v300.200.1100+0
# Precompiling packages...
#    1055.6 ms  ✓ SCS_jll
#    5659.6 ms  ? StochasticDiffEq
#    8525.8 ms  ? DifferentialEquations
#   23149.0 ms  ✓ SCS
#   2 dependencies successfully precompiled in 27 seconds. 652 already precompiled.
#   2 dependencies failed but may be precompilable after restarting julia
#   2 dependencies had output during precompilation:
# ┌ StochasticDiffEq
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ DifferentialEquations
# │  WARNING: Imported binding OrdinaryDiffEqCore.fixed_t_for_floatingpoint_error! was undeclared at import time during import to StochasticDiffEq.
# │  WARNING: Method definition issplit(OrdinaryDiffEqCore.StochasticDiffEqAlgorithm) in module OrdinaryDiffEqCore at C:\Users\eldar\.julia\packages\OrdinaryDiffEqCore\Ftbsa\src\alg_utils.jl:117 overwritten in module StochasticDiffEq at C:\Users\eldar\.julia\packages\StochasticDiffEq\cl3hU\src\alg_utils.jl:631.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
# Precompiling packages...
#    5158.8 ms  ? StochasticDiffEq
#    7629.2 ms  ? DifferentialEquations

# %%
# Считываем данные и размещаем их во фрейм:
T = DataFrame(XLSX.readtable("stock_prices.xlsx","Sheet2"))
# Out:
# 13×3 DataFrame
#  Row │ MSFT    FB      AAPL
#      │ Any     Any     Any
# ─────┼────────────────────────
#    1 │ 101.93  137.95  148.26
#    2 │ 102.8   143.8   152.29
#    3 │ 107.71  150.04  156.82
#    4 │ 107.17  149.01  157.76
#    5 │ 102.78  165.71  166.52
#    6 │ 105.67  167.33  170.41
#    7 │ 108.22  162.5   170.42
#    8 │ 110.97  161.89  172.97
#    9 │ 112.53  162.28  174.97
#   10 │ 110.51  169.6   172.91
#   11 │ 115.91  165.98  186.12
#   12 │ 117.05  164.34  191.05
#   13 │ 117.94  166.69  189.95

# %%
# Построение графика:
plot(T[!,:MSFT],label="Microsoft")
plot!(T[!,:AAPL],label="Apple")
plot!(T[!,:FB],label="FB")

# %%
# Данные о ценах на акции размещаем в матрице:
prices_matrix = Matrix(T)
# Out:
# 13×3 Matrix{Any}:
#  101.93  137.95  148.26
#  102.8   143.8   152.29
#  107.71  150.04  156.82
#  107.17  149.01  157.76
#  102.78  165.71  166.52
#  105.67  167.33  170.41
#  108.22  162.5   170.42
#  110.97  161.89  172.97
#  112.53  162.28  174.97
#  110.51  169.6   172.91
#  115.91  165.98  186.12
#  117.05  164.34  191.05
#  117.94  166.69  189.95

# %%
# Вычисление матрицы доходности за период времени:
M1 = prices_matrix[1:end-1,:]
M2 = prices_matrix[2:end,:]
# Матрица доходности:
R = (M2.-M1)./M1
# Out:
# 12×3 Matrix{Float64}:
#   0.00853527   0.0424067    0.027182
#   0.0477626    0.0433936    0.0297459
#  -0.00501346  -0.00686484   0.00599413
#  -0.040963     0.112073     0.0555274
#   0.0281183    0.00977611   0.0233606
#   0.0241317   -0.0288651    5.8682e-5
#   0.0254112   -0.00375385   0.014963
#   0.0140579    0.00240904   0.0115627
#  -0.0179508    0.0451072   -0.0117734
#   0.0488644   -0.0213443    0.0763981
#   0.00983522  -0.00988071   0.0264883
#   0.00760359   0.0142996   -0.00575766

# %%
# Матрица рисков:
risk_matrix = cov(R)
# Out:
# 3×3 Matrix{Float64}:
#   0.000659383  -0.000630653  0.000139112
#  -0.000630653   0.00152162   0.000192288
#   0.000139112   0.000192288  0.000635503

# %%
# Проверка положительной определённости матрицы рисков:
isposdef(risk_matrix)
# Out:
# true

# %%
# Доход от каждой из компаний:
r = mean(R,dims=1)[:]
# Out:
# 3-element Vector{Float64}:
#  0.012532748705136572
#  0.016563036855293173
#  0.02114580465503291

# %%
# Вектор инвестиций:
x = Variable(length(r))
# Out:
# Variable
# size: (3, 1)
# sign: real
# vexity: affine
# id: 753…560

# %%
# Объект модели:
problem = minimize(Convex.quadform(x,risk_matrix),[sum(x)==1;r'*x>=0.02;x.>=0])
# Out:
# Problem statistics
#   problem is DCP         : true
#   number of variables    : 1 (3 scalar elements)
#   number of constraints  : 5 (5 scalar elements)
#   number of coefficients : 19
#   number of atoms        : 14
#
# Solution summary
#   termination status : OPTIMIZE_NOT_CALLED
#   primal status      : NO_SOLUTION
#   dual status        : NO_SOLUTION
#
# Expression graph
#   minimize
#    └─ * (convex; positive)
#       ├─ [1;;]
#       └─ qol_elem (convex; positive)
#          ├─ norm2 (convex; positive)
#          │  └─ …
#          └─ [1.0;;]
#   subject to
#    ├─ == constraint (affine)
#    │  └─ + (affine; real)
#    │     ├─ sum (affine; real)
#    │     │  └─ …
#    │     └─ [-1;;]
#    ├─ ≥ constraint (affine)
#    │  └─ + (affine; real)
#    │     ├─ * (affine; real)
#    │     │  ├─ …
#    │     │  └─ …
#    │     └─ [-0.02;;]
#    ├─ ≥ constraint (affine)
#    │  └─ + (affine; real)
#    │     ├─ index (affine; real)
#    │     │  └─ …
#    │     └─ [0;;]
#    ⋮

# %%
# Находим решение:
solve!(problem, SCS.Optimizer)
# Out:
# ------------------------------------------------------------------
# 	       SCS v3.2.11 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 5, constraints m: 12
# cones: 	  z: primal zero / dual free vars: 1
# 	  l: linear vars: 4
# 	  q: soc vars: 7, qsize: 2
# settings: eps_abs: 1.0e-04, eps_rel: 1.0e-04, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# 	  compiled with openmp parallelization enabled
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 22, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.45e+01  1.00e+00  2.01e+01 -9.96e+00  1.00e-01  2.29e-03
#     75| 1.70e-04  3.73e-05  5.25e-06  4.62e-04  1.00e-01  2.65e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 2.65e-03s = setup: 1.18e-04s + solve: 2.54e-03s
# 	 lin-sys: 1.65e-05s, cones: 1.43e-05s, accel: 5.70e-06s
# ------------------------------------------------------------------
# objective = 0.000462
# ------------------------------------------------------------------
# [ Info: [Convex.jl] Compilation finished: 7.32 seconds, 1007.784 MiB of memory allocated
# Problem statistics
#   problem is DCP         : true
#   number of variables    : 1 (3 scalar elements)
#   number of constraints  : 5 (5 scalar elements)
#   number of coefficients : 19
#   number of atoms        : 14
#
# Solution summary
#   termination status : OPTIMAL
#   primal status      : FEASIBLE_POINT
#   dual status        : FEASIBLE_POINT
#   objective value    : 0.0005
#
# Expression graph
#   minimize
#    └─ * (convex; positive)
#       ├─ [1;;]
#       └─ qol_elem (convex; positive)
#          ├─ norm2 (convex; positive)
#          │  └─ …
#          └─ [1.0;;]
#   subject to
#    ├─ == constraint (affine)
#    │  └─ + (affine; real)
#    │     ├─ sum (affine; real)
#    │     │  └─ …
#    │     └─ [-1;;]
#    ├─ ≥ constraint (affine)
#    │  └─ + (affine; real)
#    │     ├─ * (affine; real)
#    │     │  ├─ …
#    │     │  └─ …
#    │     └─ [-0.02;;]
#    ├─ ≥ constraint (affine)
#    │  └─ + (affine; real)
#    │     ├─ index (affine; real)
#    │     │  └─ …
#    │     └─ [0;;]
#    ⋮

# %%
x
# Out:
# Variable
# size: (3, 1)
# sign: real
# vexity: affine
# id: 753…560
# value: [0.07740709795031023, 0.11606771003983785, 0.8065276266877958]

# %%
sum(x.value)
# Out:
# 1.000002434677944

# %%
r'*x.value
# Out:
# 1×1 adjoint(::Vector{Float64}) with eltype Float64:
#  0.019947233108531883

# %%
x.value .* 1000
# Out:
# 3×1 Matrix{Float64}:
#   77.40709795031023
#  116.06771003983785
#  806.5276266877958

# %%
# Подключение необходимых пакетов:
import Pkg
Pkg.add("ImageMagick")
Pkg.add("Convex")
Pkg.add("SCS")
using Images
using Convex
using SCS
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\eldar\.julia\environments\v1.12\Manifest.toml`

# %%
# Считывание исходного изображения:
using Images
Kref = load("khiam-small.jpg")
# Out:
# 283×283 Matrix{RGB{N0f8}}:
#  RGB(0.153, 0.082, 0.075)  …  RGB(0.678, 0.659, 0.675)
#  RGB(0.118, 0.047, 0.039)     RGB(0.514, 0.494, 0.51)
#  RGB(0.129, 0.059, 0.043)     RGB(0.627, 0.608, 0.624)
#  RGB(0.137, 0.067, 0.051)     RGB(0.157, 0.137, 0.153)
#  RGB(0.129, 0.063, 0.035)     RGB(0.243, 0.224, 0.239)
#  RGB(0.125, 0.059, 0.027)  …  RGB(0.184, 0.161, 0.176)
#  RGB(0.169, 0.114, 0.071)     RGB(0.208, 0.184, 0.2)
#  RGB(0.482, 0.427, 0.384)     RGB(0.153, 0.129, 0.145)
#  RGB(0.498, 0.451, 0.396)     RGB(0.141, 0.106, 0.125)
#  RGB(0.49, 0.443, 0.388)      RGB(0.161, 0.125, 0.145)
#  RGB(0.49, 0.455, 0.396)   …  RGB(0.149, 0.114, 0.125)
#  RGB(0.498, 0.463, 0.404)     RGB(0.145, 0.102, 0.118)
#  RGB(0.478, 0.451, 0.388)     RGB(0.145, 0.102, 0.118)
#  ⋮                         ⋱
#  RGB(0.51, 0.49, 0.478)       RGB(0.459, 0.431, 0.459)
#  RGB(0.49, 0.475, 0.439)      RGB(0.443, 0.424, 0.439)
#  RGB(0.51, 0.494, 0.459)      RGB(0.467, 0.443, 0.459)
#  RGB(0.482, 0.471, 0.443)     RGB(0.451, 0.404, 0.42)
#  RGB(0.463, 0.459, 0.439)  …  RGB(0.463, 0.404, 0.424)
#  RGB(0.443, 0.443, 0.435)     RGB(0.392, 0.329, 0.341)
#  RGB(0.471, 0.475, 0.482)     RGB(0.4, 0.341, 0.353)
#  RGB(0.471, 0.482, 0.502)     RGB(0.349, 0.31, 0.314)
#  RGB(0.537, 0.557, 0.58)      RGB(0.396, 0.361, 0.365)
#  RGB(0.529, 0.557, 0.588)  …  RGB(0.424, 0.4, 0.4)
#  RGB(0.541, 0.569, 0.6)       RGB(0.443, 0.408, 0.412)
#  RGB(0.541, 0.576, 0.604)     RGB(0.459, 0.412, 0.427)

# %%
K = copy(Kref)
p = prod(size(K))
missingids = rand(1:p,400)
K[missingids] .= RGBX{N0f8}(0.0,0.0,0.0)
K
Gray.(K)
# Out:
# 283×283 Matrix{Gray{N0f8}}:
#  0.102  0.063  0.078  0.094  0.055  …  0.533  0.412  0.51   0.553  0.667
#  0.067  0.098  0.075  0.055  0.09      0.384  0.51   0.506  0.584  0.502
#  0.078  0.086  0.078  0.09   0.125     0.227  0.4    0.6    0.702  0.616
#  0.086  0.067  0.075  0.094  0.098     0.29   0.435  0.659  0.706  0.145
#  0.078  0.102  0.09   0.075  0.094     0.212  0.345  0.714  0.682  0.231
#  0.075  0.075  0.078  0.086  0.094  …  0.545  0.455  0.729  0.702  0.169
#  0.125  0.098  0.086  0.086  0.078     0.349  0.588  0.627  0.467  0.192
#  0.439  0.447  0.306  0.137  0.102     0.455  0.396  0.231  0.184  0.137
#  0.459  0.455  0.451  0.455  0.404     0.4    0.392  0.196  0.102  0.118
#  0.451  0.467  0.459  0.451  0.459     0.471  0.498  0.584  0.122  0.137
#  0.459  0.459  0.459  0.455  0.455  …  0.451  0.494  0.522  0.514  0.125
#  0.467  0.451  0.459  0.475  0.463     0.388  0.376  0.576  0.741  0.118
#  0.451  0.451  0.463  0.459  0.447     0.31   0.365  0.561  0.675  0.118
#  ⋮                                  ⋱                ⋮
#  0.494  0.475  0.475  0.463  0.435     0.431  0.435  0.427  0.435  0.443
#  0.475  0.482  0.471  0.471  0.471     0.447  0.439  0.439  0.431  0.431
#  0.494  0.502  0.471  0.451  0.439     0.431  0.412  0.447  0.447  0.451
#  0.471  0.494  0.49   0.482  0.475     0.447  0.459  0.431  0.42   0.42
#  0.459  0.482  0.475  0.467  0.463  …  0.388  0.427  0.455  0.435  0.424
#  0.443  0.459  0.451  0.451  0.455     0.384  0.365  0.31   0.325  0.349
#  0.475  0.478  0.463  0.463  0.451     0.388  0.337  0.341  0.345  0.361
#  0.482  0.478  0.459  0.459  0.443     0.447  0.435  0.424  0.373  0.322
#  0.553  0.553  0.541  0.533  0.486     0.447  0.435  0.447  0.412  0.373
#  0.553  0.545  0.576  0.553  0.514  …  0.451  0.431  0.435  0.424  0.408
#  0.565  0.553  0.549  0.506  0.486     0.451  0.427  0.439  0.431  0.42
#  0.569  0.553  0.518  0.463  0.463     0.427  0.427  0.439  0.431  0.427

# %%
# Матрица цветов:
Y = Float64.(Gray.(K));
Y
# Out:
# 283×283 Matrix{Float64}:
#  0.101961   0.0627451  0.0784314  0.0941176  …  0.509804  0.552941  0.666667
#  0.0666667  0.0980392  0.0745098  0.054902      0.505882  0.584314  0.501961
#  0.0784314  0.0862745  0.0784314  0.0901961     0.6       0.701961  0.615686
#  0.0862745  0.0666667  0.0745098  0.0941176     0.658824  0.705882  0.145098
#  0.0784314  0.101961   0.0901961  0.0745098     0.713725  0.682353  0.231373
#  0.0745098  0.0745098  0.0784314  0.0862745  …  0.729412  0.701961  0.168627
#  0.12549    0.0980392  0.0862745  0.0862745     0.627451  0.466667  0.192157
#  0.439216   0.447059   0.305882   0.137255      0.231373  0.184314  0.137255
#  0.458824   0.454902   0.45098    0.454902      0.196078  0.101961  0.117647
#  0.45098    0.466667   0.458824   0.45098       0.584314  0.121569  0.137255
#  0.458824   0.458824   0.458824   0.454902   …  0.521569  0.513725  0.12549
#  0.466667   0.45098    0.458824   0.47451       0.576471  0.741176  0.117647
#  0.45098    0.45098    0.462745   0.458824      0.560784  0.67451   0.117647
#  ⋮                                           ⋱  ⋮
#  0.494118   0.47451    0.47451    0.462745      0.427451  0.435294  0.443137
#  0.47451    0.482353   0.470588   0.470588      0.439216  0.431373  0.431373
#  0.494118   0.501961   0.470588   0.45098       0.447059  0.447059  0.45098
#  0.470588   0.494118   0.490196   0.482353      0.431373  0.419608  0.419608
#  0.458824   0.482353   0.47451    0.466667   …  0.454902  0.435294  0.423529
#  0.443137   0.458824   0.45098    0.45098       0.309804  0.32549   0.34902
#  0.47451    0.478431   0.462745   0.462745      0.341176  0.345098  0.360784
#  0.482353   0.478431   0.458824   0.458824      0.423529  0.372549  0.321569
#  0.552941   0.552941   0.541176   0.533333      0.447059  0.411765  0.372549
#  0.552941   0.545098   0.576471   0.552941   …  0.435294  0.423529  0.407843
#  0.564706   0.552941   0.54902    0.505882      0.439216  0.431373  0.419608
#  0.568627   0.552941   0.517647   0.462745      0.439216  0.431373  0.427451

# %%
correctids = findall(Y[:].!=0)
X = Convex.Variable(size(Y))
problem = minimize(nuclearnorm(X))
problem.constraints += X[correctids]==Y[correctids]
# Out:
# 1-element Vector{Constraint}:
#  == constraint (affine)
# └─ + (affine; real)
#    ├─ index (affine; real)
#    │  └─ 283×283 real variable (id: 362…354)
#    └─ 79693×1 Matrix{Float64}

# %%
# Находим решение:
solve!(problem, SCS.Optimizer(eps=1e-3, alpha=1.5))
# Out:
# UndefVarError: `MOI_wrapper` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] getproperty(x::Module, f::Symbol)
#    @ Base .\Base_compiler.jl:47
#  [2] top-level scope
#    @ In[65]:2
#  [3] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %%
using JuMP
using GLPK
# Создаём модель
model = Model(GLPK.Optimizer)
# Определяем переменные (с учётом ограничений x1 ≤ 10, x2 ≥ 0, x3 ≥ 0)
@variable(model, 0 <= x1 <= 10)
@variable(model, x2 >= 0)
@variable(model, x3 >= 0)
# Задаём целевую функцию (максимизация)
@objective(model, Max, x1 + 2x2 + 5x3)
# Добавляем ограничения
@constraint(model, -x1 + x2 + 3x3 <= -5)
@constraint(model, x1 + 3x2 - 7x3 <= 10)
# Решаем задачу
optimize!(model)
# Выводим результаты
println("Статус решения: ", termination_status(model))
println("Оптимальное значение целевой функции: ", objective_value(model))
println("Значения переменных: ")
println("x1 = ", value(x1))
println("x2 = ", value(x2))
println("x3 = ", value(x3))
# Out:
# Статус решения: OPTIMAL
# Оптимальное значение целевой функции: 19.0625
# Значения переменных:
# x1 = 10.0
# x2 = 2.1875
# x3 = 0.9375

# %%
using JuMP
using GLPK
# Данные задачи
A = [1 1 9 5; 3 5 0 8; 2 0 6 13]
b = [7, 3, 5]
c = [1, 3, 5, 2]
# Создание модели
model = Model(GLPK.Optimizer)
# Объявление переменных (вектор x)
n = size(A, 2)
@variable(model, x[1:n] >= 0)
# Целевая функция (cᵀ * x)
@objective(model, Max, dot(c, x))
# Ограничения (Ax ≤ b)
@constraint(model, A * x .<= b)
# Решение задачи
optimize!(model)
# Вывод результатов
println("Оптимальное значение целевой функции: ", objective_value(model))
println("Оптимальные значения переменных x: ", value.(x))
# Out:
# Оптимальное значение целевой функции: 5.355555555555556
# Оптимальные значения переменных x: [0.0, 0.6, 0.7111111111111111, 0.0]

# %%
using Convex
using SCS
using Random
# Устанавливаем seed для воспроизводимости (опционально)
Random.seed!(123)
# Задаём размеры матрицы A (m × n)
m, n = 3, 4  # пример размеров, можно изменить
# Генерируем случайную матрицу A и вектор b
A = randn(m, n)  # случайная матрица m×n
b = randn(m)     # случайный вектор длины m
# Создаём переменную оптимизации x (вектор длины n)
x = Variable(n)
# Формулируем целевую функцию: ∥Ax – b∥₂²
objective = sumsquares(A * x - b)  # sumsquares вычисляет сумму квадратов элементов вектора
# Задаём ограничение: x ≥ 0
constraints = [x >= 0]
# Создаём задачу оптимизации
problem = minimize(objective, constraints)
# Решаем задачу с помощью SCS
solve!(problem, SCS.Optimizer)
# Выводим результаты
println("Оптимальное значение x: ", x.value)
println("Минимальное значение ∥Ax – b∥₂²: ", objective_value(model))(problem)
# Out:
# ------------------------------------------------------------------
# 	       SCS v3.2.11 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 5, constraints m: 9
# cones: 	  l: linear vars: 4
# 	  q: soc vars: 5, qsize: 1
# settings: eps_abs: 1.0e-04, eps_rel: 1.0e-04, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# 	  compiled with openmp parallelization enabled
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 18, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.21e+01  1.00e+00  3.08e+01 -1.53e+01  1.00e-01  2.33e-04
#    225| 1.94e-04  2.22e-06  5.31e-06  1.32e-05  1.00e-01  1.79e-03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.79e-03s = setup: 1.03e-04s + solve: 1.69e-03s
# 	 lin-sys: 6.24e-05s, cones: 3.13e-05s, accel: 3.76e-05s
# ------------------------------------------------------------------
# objective = 0.000013
# ------------------------------------------------------------------
# Оптимальное значение x: [-2.5278850079144356e-5; 3.937682925084042; 1.2944095948975405; 4.543555600991451;;]
# Минимальное значение ∥Ax – b∥₂²: 5.355555555555556
# [ Info: [Convex.jl] Compilation finished: 0.01 seconds, 245.828 KiB of memory allocated
# MethodError: objects of type Nothing are not callable
# The object of type `Nothing` exists, but no method is defined for this combination of argument types when trying to treat it as a callable object.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[71]:23
#  [2] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489
